# %%
import numpy as np

# %% [markdown]
# # Задание 1

# %% [raw]
# Исследовать на линейную зависимость:
# 𝑓1(𝑥)=𝑒𝑥,𝑓2(𝑥)=1,𝑓3(𝑥)=𝑥+1,𝑓4(𝑥)=𝑥−𝑒𝑥.

# %% [raw]
# # посмотрим, можно ли выразить одну функцию через другие
#
# f4 = f3 - f2 - f1
# x - e*x = (x+1) - 1 - e*x
#
# # коэффициенты
#
# a1 = -1
# a2 = -1
# a3 = 1
# a4 = 1

# %% [raw]
# Ответ: функции линейно-зависимы

# %% [markdown]
# # Задание 2

# %% [raw]
# Исследовать на линейную зависимость:
# 𝑓1(𝑥)=2,𝑓2(𝑥)=𝑥,𝑓3(𝑥)=𝑥2,𝑓4(𝑥)=(𝑥+1)^2

# %% [raw]
# Решение
#
# f4 = x^2 + 2*x + 1
#
# f4 = f3 + 2*f2 + 0.5*f1
# x^2 + 2*x + 1 = x^2 + 2*x + 1
#
# a1 = 0.5
# a2 = 2
# a3 = 1
# a4 = 1

# %% [raw]
# Ответ
#
# функции линейно-зависимы

# %% [markdown]
# # Задание 3

# %% [raw]
# Найти координаты вектора  𝑥=(2,3,5)∈ℝ3  в базисе  𝑏1=(0,0,10) ,  𝑏2=(2,0,0) ,  𝑏3=(0,1,0) .

# %% [raw]
# Решение
#
# x = a2*b2 + a3*b3 + a1*b1
# 2 + 3 + 5 = a2*2 + a3*1 + a1*10
# 2 + 3 + 5 = 1*2 + 3*1 + 0.5*10

# %% [raw]
# Ответ: (1, 3, 0.5)

# %% [markdown]
# # Задание 4

# %% [raw]
# Найти координаты вектора  3𝑥2−2𝑥+2∈ℝ3[𝑥]:
#     а) в базисе  1 ,  𝑥 ,  𝑥2 ;
#     б) в базисе  𝑥2 ,  𝑥−1 ,  1 .

# %% [raw]
# Решение a:
#
# 3*x^2 - 2*x + 2 = a3*b3 + a2*b2 + a1*b1
# 3*x^2 - 2*x + 2 = a3*x^2 + a2*x + a1*1
# 3*x^2 - 2*x + 2 = 3*x^2 + (-2)*x + 2*1
#
# Ответ: (2, -2, 3)

# %% [raw]
# Решение b:
#
# 3*x^2 - 2*x + 2 = a1*b1 + a2*b2 + a3*b3
# 3*x^2 - 2*x + 2 = a1*x^2 + a2*(x-1) + a3*1
# 3*x^2 - 2*x + 2 = 3*x^2 + a2*x-a2 + a3*1
# 3*x^2 - 2*x + 2 = 3*x^2 + 2*x-2 + 4*1
# 3*x^2 - 2*x + 2 = 3*x^2 + 2*x + 2
#
# Ответ: (3, 2, 4)

# %% [markdown]
# # Задание 5

# %% [raw]
# Найти скалярное произведение векторов  𝑥,𝑦∈ℝ :
# а)  𝑥=(0,−3,6), 𝑦=(−4,7,9);
# б)  𝑥=(7,−4,0,1), 𝑦=(−3,1,11,2).

# %% [raw]
# Решение a:
#
# x * y = 0*(-4) + (-3)*7 + 6*9 = -21 + 54 = 33

# %% [raw]
# Решение b:
#
# x * y = 7*(-3) + (-4)*1 + 0*11 + 1*2 = -21 - 4 + 2 = -23

# %% [markdown]
# # Задание 6

# %% [raw]
# Найти нормы векторов  (4,2,4)  и  (12,3,4)  и угол между ними.

# %% [raw]
# Решение
#
# Манхэттенская норма (4,2,4) = abs(4) + abs(2) + abs(4) = 10
# Манхэттенская норма (12,3,4) = abs(12) + abs(3) + abs(4) = 19
#
# Евклидова норма (4,2,4) = sqrt(4^2 + 2^2 + 4^2) = sqrt(16 + 4 + 16) = sqrt(36) = 6
# Евклидова норма (12,3,4) = sqrt(12^2 + 3^2 + 4^2) = sqrt(144 + 9 + 16) = sqrt(169) = 13
#
# Определим косинус угла между векторами
# C = (4*12 + 2*3 + 4*4) / 6 * 13 = (48 + 6 + 16) / 78 = 70 / 78 = 0.9 (угол примерно 26 градусов)

# %% [markdown]
# # Задание 7

# %% [raw]
# Будет ли линейное пространство евклидовым, если за скалярное произведение принять:
# а) произведение длин векторов;
# б) утроенное обычное скалярное произведение векторов?

# %% [raw]
# Для этого нужно, чтобы соблюдались аксиомы:
#
# 1)  (𝑥,𝑦)=(𝑦,𝑥);
# 2)  (𝜆𝑥,𝑦)=𝜆(𝑥,𝑦);
# 3)  (𝑥1+𝑥2,𝑦)=(𝑥1,𝑦)+(𝑥2,𝑦);
# 4)  (𝑥,𝑥)≥0 , причем  (𝑥,𝑥)=0⇔𝑥=0.

# %% [raw]
# Решение a
#
# Длина — это число. Проверим на примерах векторов (4,2,4) и (12,3,4)
#
# Евклидовы нормы были посчитаны в предыдущей задаче: 6 и 13
# Проверим аксиомы:
# 1. 6*13 = 13*6 — аксиома точно соблюдается, так как мы можем переставлять множители местами.
#
# 2. k = 2
# (4,2,4) * 2 = (8, 4, 8)
# Е норма = sqrt(64 + 16 + 64) = 12
# 12 * 13 = (6 * 13) * 2
# 156 = 156
# аксиома соблюдается
#
# 3.
# (4 + 2 + 4) * (12,3,4) = 10 * (12,3,4) = (120, 30, 40)
# 4 * (12,3,4) + 2 * (12,3,4) + 4 * (12,3,4) = (48, 12, 16) + (24, 6, 8) + (48, 12, 16) = (120, 30, 40)
# аксиома соблюдается
#
# 4. аксиома соблюдается
#
# Ответ: да

# %% [raw]
# Решение b
#
# Можно быть уверенным, что аксиомы соблюдаются, так как нам не важно, на какое число умножить множители.

# %% [markdown]
# # Задание 8

# %% [raw]
# Какие из нижеперечисленных векторов образуют ортонормированный базис в линейном пространстве  ℝ3 :
# а)  (1,0,0),(0,0,1);
# б)  (1/2‾√,−1/2‾√,0),(1/2‾√,1/2‾√,0),(0,0,1);
# в)  (1/2,−1/2,0),(0,1/2,1/2),(0,0,1);
# г)  (1,0,0),(0,1,0),(0,0,1)?

# %% [raw]
# Отонормированный базис (1, 0, 0) (0, 1, 0) (0, 0, 1)

# %% [raw]
# Решение
#
# а) — нет, так как в R3 нужна третья координата.
#
# б) — первые 2 вектора равны друг другу, значит нет.
#
# в)
#
# г) да
